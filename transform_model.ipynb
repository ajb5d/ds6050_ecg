# %%
import tensorflow as tf
import numpy as np
from pathlib import Path
from datetime import datetime
import os

# %%
DATA_PATH = Path("/scratch/ajb5d/ecg/tfrecords/")
TRAIN_RECS = list(DATA_PATH.glob("train*.tfrecords"))
VAL_RECS = list(DATA_PATH.glob("train*.tfrecords"))

# %%
BATCH_SIZE = 64

record_format = {
    'ecg/data': tf.io.FixedLenSequenceFeature([], tf.float32, allow_missing=True),
    'age': tf.io.FixedLenFeature([], tf.float32),
    'gender': tf.io.FixedLenFeature([], tf.int64),
}

def _parse_record(record):
    example = tf.io.parse_single_example(record, record_format)
    ecg_data = tf.reshape(example['ecg/data'], [5000,12])
    label = example['age']
    return ecg_data, label

def drop_na_ages(x,y):
    return not tf.math.reduce_any(tf.math.is_nan(y))

def age_lt_90(x,y):
    return tf.math.reduce_all(tf.math.less_equal(y, tf.constant([90.0])))

def load_dataset(filenames):
    ignore_order = tf.data.Options()
    ignore_order.experimental_deterministic = False
    dataset = tf.data.TFRecordDataset(filenames)
    dataset = dataset.with_options(ignore_order)
    dataset = dataset.map(_parse_record, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.filter(drop_na_ages)
    dataset = dataset.filter(age_lt_90)
    return dataset

def get_dataset(filenames, labeled=True):
    dataset = load_dataset(filenames)
    dataset = dataset.shuffle(2048)
    dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
    dataset = dataset.batch(BATCH_SIZE)
    return dataset

# %%
train_dataset = get_dataset(TRAIN_RECS)
val_dataset = get_dataset(VAL_RECS)

# %%
#https://keras.io/examples/timeseries/timeseries_transformer_classification/
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = tf.keras.layers.MultiHeadAttention(key_dim=head_size, num_heads=num_heads,dropout=dropout)(x,x)
    x = tf.keras.layers.Dropout(dropout)(x)
    res = x + inputs
    
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(res)
    x = tf.keras.layers.Conv1D(filters=ff_dim, kernel_size=1, activation='relu')(x)
    x = tf.keras.layers.Dropout(dropout)(x)
    x = tf.keras.layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res

# %%
input_layer = tf.keras.layers.Input(shape=(5000, 12))
x = input_layer
x = transformer_encoder(x, head_size=256, num_heads=4, ff_dim=4*12, dropout=0)
x = tf.keras.layers.MaxPooling1D()(x)

x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.Dense(128)(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Activation('relu')(x)
x = tf.keras.layers.Dropout(0.5)(x)
x = tf.keras.layers.Dense(64)(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Activation('relu')(x)
x = tf.keras.layers.Dropout(0.5)(x)
x = tf.keras.layers.Dense(1)(x)

model = tf.keras.models.Model(input_layer, x)

model.compile(
    optimizer='adam',
    loss=tf.keras.losses.MeanSquaredError(),
    metrics=['mse', 'mae']
)
# Out:
# 2023-10-21 13:59:23.879959: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1636] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1310 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:81:00.0, compute capability: 8.6

# %%
def make_checkpoint_dir(data_path, label):
    current_datetime = datetime.now()
    formatted_datetime = current_datetime.strftime("%Y-%m-%d_%H-%M-%S")
    output_dir = f"{label}-{formatted_datetime}"
    output_path = f"{data_path}/{output_dir}"
    
    if not os.path.exists(output_path):
        os.makedirs(output_path)
    
    return output_path

# %%
callbacks = [
    tf.keras.callbacks.TerminateOnNaN(),
    tf.keras.callbacks.ReduceLROnPlateau(),
    tf.keras.callbacks.ModelCheckpoint(make_checkpoint_dir("data/models", "cnn-age"))
]

model.fit(train_dataset, epochs=1, validation_data=val_dataset, callbacks=callbacks)
# Out:
# Epoch 1/10
# 2023-10-21 14:01:12.606123: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 1630998941832947191
# 2023-10-21 14:01:12.606167: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 4233768752812478237
# ---------------------------------------------------------------------------
# PermissionDeniedError                     Traceback (most recent call last)
# Cell In[11], line 7
#       1 callbacks = [
#       2     tf.keras.callbacks.TerminateOnNaN(),
#       3     tf.keras.callbacks.ReduceLROnPlateau(),
#       4     tf.keras.callbacks.ModelCheckpoint(make_checkpoint_dir("data/models", "cnn-age"))
#       5 ]
# ----> 7 model.fit(train_dataset, epochs=10, validation_data=val_dataset, callbacks=callbacks)
#
# File /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# PermissionDeniedError: Graph execution error:
#
# Detected at node 'IteratorGetNext' defined at (most recent call last):
#     File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "/usr/local/lib/python3.10/dist-packages/ipykernel/__main__.py", line 5, in <module>
#       app.launch_new_instance()
#     File "/usr/local/lib/python3.10/dist-packages/traitlets/config/application.py", line 1043, in launch_instance
#       app.start()
#     File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelapp.py", line 736, in start
#       self.io_loop.start()
#     File "/usr/local/lib/python3.10/dist-packages/tornado/platform/asyncio.py", line 195, in start
#       self.asyncio_loop.run_forever()
#     File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#       self._run_once()
#     File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#       handle._run()
#     File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#       await self.process_one()
#     File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 505, in process_one
#       await dispatch(*args)
#     File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#       await result
#     File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 740, in execute_request
#       reply_content = await reply_content
#     File "/usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py", line 422, in do_execute
#       res = shell.run_cell(
#     File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 546, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#       result = self._run_cell(
#     File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#       result = runner(coro)
#     File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/tmp/ipykernel_280746/2430699979.py", line 7, in <module>
#       model.fit(train_dataset, epochs=10, validation_data=val_dataset, callbacks=callbacks)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1742, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1338, in train_function
#       return step_function(self, iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1321, in step_function
#       data = next(iterator)
# Node: 'IteratorGetNext'
# Detected at node 'IteratorGetNext' defined at (most recent call last):
#     File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "/usr/local/lib/python3.10/dist-packages/ipykernel/__main__.py", line 5, in <module>
#       app.launch_new_instance()
#     File "/usr/local/lib/python3.10/dist-packages/traitlets/config/application.py", line 1043, in launch_instance
#       app.start()
#     File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelapp.py", line 736, in start
#       self.io_loop.start()
#     File "/usr/local/lib/python3.10/dist-packages/tornado/platform/asyncio.py", line 195, in start
#       self.asyncio_loop.run_forever()
#     File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#       self._run_once()
#     File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#       handle._run()
#     File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#       await self.process_one()
#     File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 505, in process_one
#       await dispatch(*args)
#     File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#       await result
#     File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 740, in execute_request
#       reply_content = await reply_content
#     File "/usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py", line 422, in do_execute
#       res = shell.run_cell(
#     File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 546, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#       result = self._run_cell(
#     File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#       result = runner(coro)
#     File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/tmp/ipykernel_280746/2430699979.py", line 7, in <module>
#       model.fit(train_dataset, epochs=10, validation_data=val_dataset, callbacks=callbacks)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1742, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1338, in train_function
#       return step_function(self, iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1321, in step_function
#       data = next(iterator)
# Node: 'IteratorGetNext'
# 2 root error(s) found.
#   (0) PERMISSION_DENIED:  /scratch/ajb5d/ecg/tfrecords/train-0593.tfrecords; Permission denied
# 	 [[{{node IteratorGetNext}}]]
# 	 [[IteratorGetNext/_2]]
#   (1) PERMISSION_DENIED:  /scratch/ajb5d/ecg/tfrecords/train-0593.tfrecords; Permission denied
# 	 [[{{node IteratorGetNext}}]]
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_train_function_3927]

# %%
TRAIN_RECS
# Out:
# [PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0593.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0745.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0213.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0772.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0405.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0776.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0121.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0393.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0740.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0048.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0283.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0794.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0410.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0369.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0416.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0522.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0793.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0204.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0958.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0385.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0596.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0977.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0044.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0801.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0475.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0001.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0096.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0165.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0007.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0077.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0615.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0514.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0612.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0336.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0904.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0967.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0784.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0126.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0343.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0500.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0191.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0368.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0149.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0791.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0484.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0887.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0895.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0277.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0315.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0142.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0583.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0409.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0168.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0147.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0065.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0650.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0933.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0013.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0542.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0527.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0270.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0346.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0870.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0906.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0602.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0627.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0427.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0197.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0796.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0585.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0646.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0253.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0032.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0979.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0588.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0771.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0803.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0356.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0848.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0913.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0138.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0193.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0969.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0401.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0180.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0308.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0029.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0945.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0380.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0690.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0058.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0289.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0671.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0834.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0972.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0162.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0054.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0470.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0623.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0661.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0015.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0613.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0924.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0551.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0140.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0107.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0782.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0557.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0901.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0651.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0696.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0735.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0655.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0534.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0761.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0575.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0713.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0582.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0505.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0954.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0189.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0064.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0034.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0508.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0424.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0080.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0133.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0948.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0045.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0265.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0148.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0386.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0322.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0188.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0178.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0117.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0136.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0297.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0145.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0935.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0144.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0847.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0744.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0068.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0709.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0648.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0031.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0538.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0230.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0131.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0108.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0562.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0202.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0928.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0483.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0854.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0742.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0160.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0320.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0664.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0726.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0833.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0640.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0828.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0434.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0212.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0078.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0285.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0453.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0499.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0363.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0710.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0554.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0233.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0931.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0676.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0975.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0741.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0439.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0910.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0333.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0693.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0040.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0502.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0501.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0919.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0203.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0897.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0223.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0314.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0886.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0770.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0286.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0944.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0305.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0632.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0252.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0261.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0909.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0400.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0109.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0182.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0699.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0705.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0119.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0395.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0903.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0036.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0748.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0299.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0207.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0724.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0752.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0284.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0503.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0707.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0686.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0679.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0936.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0883.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0463.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0152.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0688.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0578.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0042.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0211.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0507.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0584.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0256.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0577.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0004.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0159.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0856.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0467.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0367.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0737.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0226.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0053.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0196.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0280.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0480.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0317.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0348.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0319.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0823.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0692.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0361.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0377.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0330.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0364.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0734.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0250.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0888.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0775.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0845.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0293.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0916.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0267.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0599.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0112.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0760.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0759.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0164.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0621.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0885.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0139.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0241.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0927.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0051.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0603.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0089.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0186.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0537.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0751.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0946.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0733.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0373.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0258.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0302.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0629.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0822.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0618.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0459.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0921.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0232.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0247.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0455.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0520.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0099.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0821.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0275.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0288.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0659.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0383.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0469.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0426.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0257.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0861.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0412.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0365.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0303.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0841.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0221.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0622.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0041.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0590.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0396.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0005.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0185.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0132.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0039.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0840.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0345.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0384.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0492.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0214.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0437.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0635.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0344.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0497.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0819.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0880.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0548.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0550.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0245.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0532.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0912.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0539.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0376.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0619.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0290.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0339.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0209.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0525.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0125.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0155.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0425.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0481.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0858.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0971.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0105.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0908.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0586.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0198.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0716.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0677.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0086.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0225.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0457.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0239.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0728.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0371.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0890.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0652.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0645.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0712.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0851.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0922.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0184.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0366.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0130.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0865.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0049.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0963.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0370.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0720.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0429.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0143.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0406.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0082.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0291.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0662.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0614.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0753.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0006.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0461.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0859.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0681.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0166.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0756.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0914.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0227.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0462.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0510.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0704.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0844.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0043.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0511.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0085.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0172.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0174.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0956.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0896.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0460.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0678.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0010.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0016.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0307.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0482.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0192.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0003.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0531.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0309.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0359.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0263.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0656.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0727.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0477.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0493.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0769.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0768.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0157.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0103.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0123.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0088.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0528.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0473.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0183.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0161.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0809.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0246.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0836.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0431.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0251.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0329.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0810.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0466.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0715.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0966.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0255.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0743.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0033.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0639.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0444.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0788.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0446.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0826.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0587.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0240.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0891.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0855.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0892.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0781.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0591.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0398.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0281.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0313.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0454.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0698.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0321.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0216.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0014.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0831.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0414.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0978.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0347.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0234.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0876.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0509.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0905.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0353.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0934.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0187.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0175.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0607.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0249.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0181.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0697.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0238.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0055.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0942.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0755.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0110.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0950.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0046.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0732.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0420.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0780.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0674.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0747.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0943.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0949.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0773.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0816.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0839.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0837.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0268.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0666.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0350.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0038.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0564.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0276.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0799.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0154.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0022.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0611.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0456.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0104.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0260.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0436.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0555.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0783.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0243.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0544.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0601.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0725.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0636.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0561.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0970.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0805.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0526.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0930.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0774.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0272.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0011.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0028.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0224.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0486.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0546.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0479.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0170.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0581.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0675.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0516.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0853.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0907.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0767.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0106.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0717.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0498.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0027.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0190.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0349.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0875.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0296.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0953.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0702.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0445.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0228.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0519.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0670.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0374.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0074.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0306.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0815.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0219.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0491.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0328.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0973.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0200.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0536.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0411.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0668.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0792.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0063.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0789.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0134.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0962.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0323.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0625.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0852.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0706.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0825.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0604.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0020.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0304.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0929.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0332.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0872.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0205.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0468.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0884.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0052.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0418.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0124.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0167.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0893.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0035.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0215.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0559.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0488.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0889.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0072.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0798.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0806.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0777.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0471.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0849.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0047.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0300.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0606.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0451.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0379.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0609.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0754.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0102.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0390.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0331.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0718.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0391.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0811.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0573.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0641.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0113.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0757.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0877.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0375.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0863.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0218.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0278.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0787.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0443.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0179.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0357.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0091.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0335.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0075.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0965.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0171.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0236.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0947.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0009.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0163.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0342.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0298.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0325.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0974.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0902.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0237.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0515.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0634.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0229.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0541.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0358.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0496.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0600.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0407.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0423.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0408.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0419.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0487.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0637.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0631.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0524.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0738.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0643.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0231.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0266.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0259.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0201.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0802.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0812.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0327.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0101.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0597.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0269.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0513.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0070.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0952.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0098.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0037.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0703.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0061.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0490.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0127.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0868.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0620.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0495.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0869.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0129.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0254.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0030.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0360.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0939.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0552.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0957.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0352.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0862.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0489.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0915.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0057.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0394.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0653.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0624.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0955.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0723.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0749.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0687.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0968.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0923.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0535.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0118.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0941.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0381.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0169.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0440.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0626.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0605.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0338.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0763.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0711.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0025.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0762.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0642.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0867.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0731.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0340.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0672.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0730.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0959.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0264.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0382.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0721.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0413.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0669.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0217.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0417.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0521.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0937.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0813.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0795.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0779.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0485.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0156.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0842.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0403.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0067.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0685.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0271.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0850.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0682.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0087.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0450.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0595.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0337.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0874.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0008.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0100.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0066.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0518.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0553.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0372.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0002.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0506.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0691.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0657.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0764.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0911.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0310.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0362.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0694.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0388.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0326.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0663.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0790.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0512.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0797.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0021.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0137.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0830.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0120.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0898.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0658.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0428.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0638.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0758.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0378.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0210.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0729.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0173.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0083.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0719.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0860.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0090.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0114.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0576.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0925.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0092.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0122.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0079.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0397.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0579.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0158.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0094.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0111.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0940.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0644.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0818.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0616.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0543.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0630.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0804.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0442.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0076.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0494.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0279.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0829.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0392.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0435.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0433.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0273.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0572.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0540.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0951.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0786.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0785.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0282.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0665.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0318.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0766.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0565.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0235.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0832.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0292.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0017.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0073.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0024.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0683.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0835.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0062.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0351.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0355.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0920.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0843.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0116.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0081.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0432.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0879.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0649.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0563.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0530.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0592.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0026.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0824.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0695.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0689.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0556.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0019.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0151.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0294.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0060.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0341.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0402.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0684.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0059.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0846.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0194.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0222.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0448.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0608.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0195.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0472.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0568.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0708.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0000.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0866.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0736.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0421.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0878.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0128.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0750.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0545.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0960.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0517.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0701.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0447.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0700.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0176.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0838.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0633.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0598.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0097.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0560.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0458.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0316.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0478.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0474.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0714.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0673.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0399.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0071.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0449.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0871.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0654.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0746.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0594.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0441.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0820.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0199.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0580.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0533.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0894.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0529.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0262.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0926.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0115.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0558.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0135.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0589.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0465.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0918.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0547.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0857.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0404.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0739.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0295.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0574.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0617.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0807.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0765.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0012.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0917.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0660.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0680.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0722.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0900.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0244.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0220.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0354.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0647.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0389.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0141.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0093.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0069.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0206.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0567.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0095.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0430.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0146.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0248.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0817.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0153.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0287.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0610.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0571.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0438.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0961.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0873.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0387.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0899.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0050.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0452.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0938.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0976.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0415.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0208.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0324.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0084.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0814.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0301.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0177.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0932.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0150.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0549.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0882.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0569.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0800.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0023.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0864.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0312.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0808.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0667.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0570.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0476.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0056.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0523.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0242.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0504.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0964.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0464.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0274.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0334.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0311.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0422.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0827.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0628.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0018.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0778.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0881.tfrecords'),
#  PosixPath('/scratch/ajb5d/ecg/tfrecords/train-0566.tfrecords')]
